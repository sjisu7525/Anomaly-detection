# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %cd /content/drive/MyDrive/논문 번역/특허법인제출용

# !pip install import_ipynb
# import import_ipynb

# %%
import pandas as pd
from Anomaly_detection import detect_anomaly

data = pd.read_csv('./DATA/data2.csv')
lags = 100
list_ae = [5,40,5,40]
stride = 10
dims = [15,7,2]

# %%
data, RE_final_test_cycle, RE_final_test_trend, score_df = detect_anomaly(data, lags, dims, list_ae, stride)
# Out:
# ...
# 6/6 [==============================] - 0s 2ms/step
#               value
# Acc        0.993452
# F1-score   0.946341
# Recall     0.906542
# Precision  0.989796
