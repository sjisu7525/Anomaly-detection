# %%
import statsmodels.api as sm

def decompose(data_, lamda = 100):

  cycle, trend = sm.tsa.filters.hpfilter(data_,lamda)

  trend[0:5] = trend.mean()
  trend[-5:] = trend.mean()

  return cycle, trend
